# %% [markdown]
# # 11강. 시계열 데이터 분해법

# %% [markdown]
# ## set up

# %%
import pandas as pd 
import matplotlib.pyplot as plt 
# %matplotlib inline 
import seaborn as sns 
from pandas_datareader import data as pdr
data = pdr.get_data_yahoo("GS", start="1999-05-04", end="2017-09-28")

# %%
def plot(df,title):
    plt.figure(figsize=[20,5])
    plt.plot(df)
    plt.title(title)
    plt.show()
    
plot(data[['Close']],"Goldman Sachs Stock Price")

# %% [markdown]
# 단순 이동 평균
# - 과거 일정 기간 데이터들을 평균함으로써 시계열을 smoothing 함
# - pandas의 rolling 함수를 이용해서 데이터를 밑으로 내리고 mean을 구합니다
# - 아래의 경우 moving average는 산술평균을 통해서 동일한 weight가 들어가게 됩니다.

# %%
def plot(df,title):
    plt.figure(figsize=[20,5])
    plt.plot(df,label = "Original")
    plt.plot(df.rolling(100).mean(),label = "MA:10")
    plt.legend()
    plt.title(title)
    plt.ylabel("Price($)",rotation=90)
#     plt.yticks(rotaion =90)
    
    plt.show()
    
plot(data[['Close']],"Goldman Sachs Stock Price")

# %%
from statsmodels.tsa.seasonal import seasonal_decompose 

result = seasonal_decompose(data['Close'], model = "additive",period= 250)

plt.rcParams['figure.figsize'] = [20, 8]
result.plot()
plt.show()

# %% [markdown]
# <img src='./IMG/img5.png'>

# %%
pd.infer_freq(data.index)

# %%
 # Holt-winters 모형
from statsmodels.tsa.holtwinters import SimpleExpSmoothing   
# Set the frequency of the date time index as Monthly start as indicated by the data
data.index.freq = None
# Set the value of Alpha and define m (Time Period)
m = 12
alpha = 1/(2*m)

# %%
data['HWES1'] = SimpleExpSmoothing(data['Close']).fit(smoothing_level=alpha,optimized=False,use_brute=True).fittedvalues
data[['Close','HWES1']].plot(title='Holt Winters Single Exponential Smoothing');
# Out:
# C:\Users\sk\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# C:\Users\sk\Anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:427: FutureWarning: After 0.13 initialization must be handled at model creation
#   warnings.warn(

# %%
data['level'] =  SimpleExpSmoothing(data['Close']).fit(smoothing_level=alpha,optimized=False,use_brute=True).level
data['trend'] =  SimpleExpSmoothing(data['Close']).fit(smoothing_level=alpha,optimized=False,use_brute=True).trend
data['season'] =  SimpleExpSmoothing(data['Close']).fit(smoothing_level=alpha,optimized=False,use_brute=True).season
# Out:
# C:\Users\sk\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# C:\Users\sk\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# C:\Users\sk\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'

# %%
def hwe_plot(fitted_function):
    fig,ax = plt.subplots(nrows=4,figsize=[20,8],sharex=True)
    ax[0].plot(fitted_function.fittedvalues,label='raw')
    ax[1].plot(fitted_function.level,label= 'level')
    ax[1].set_ylabel("level")
    ax[2].plot(fitted_function.trend,label= 'trend')
    ax[2].set_ylabel("level")
    ax[3].plot(fitted_function.season,label= 'season')
    ax[3].set_ylabel("level")

# %%
hwe_plot(SimpleExpSmoothing(data['Close']).fit(smoothing_level=alpha,optimized=False,use_brute=True))
# Out:
# C:\Users\sk\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'

# %% [markdown]
# ## 또 다른 분해법 (STL (Seasonal Decomposition of Time Series by LOESS) 모형)

# %% [markdown]
# `LOESS` (LOcal rEgreSSion - lowess: locally weighted scatter plot smoother)
#
# - 일반적으로 locally weighted polynomial regression으로 불림
# - 비모수 회귀 분석 (non-parametric regression)
#
# smoothing을 조금 더 세련되게 해주는 방법

# %% [markdown]
# local polynomial regression: x(0) 근처 데이터들을 polynomial로 fitting
#
# <img src = './IMG/img6.png'>

# %% [markdown]
# STL 함수
#
# - 시계열 변환
# - STL 모형 파라미터 계싼 (예측 모형 training)
# - Decomposition 그래프
# - 예측

# %%
gs = data[['Close']]

# %%
STL(gs['Close'],period=250).
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-40-fc97df876291> in <module>
# ----> 1 STL(gs['Close'],period=250).fit().predict()
#       2 plt.show()
#
# AttributeError: 'DecomposeResult' object has no attribute 'predict'

# %%
from statsmodels.tsa.seasonal import STL 
from statsmodels.tsa.api import STLForecast
from statsmodels.tsa.arima.model import ARIMA

def stl_plot(df):
    
    STL(df['Close'],period=250).fit().plot()
    # predict 
    stlf = STLForecast(df['Close'],ARIMA, period = 250,model_kwargs = {'order':(2,1,0)})
    res = stlf.fit()
    forecasts = res.forecast(12)
    print(forecasts)
    plt.show()

stl_plot(gs)
# Out:
# C:\Users\sk\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# C:\Users\sk\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# C:\Users\sk\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# ...
